# %% [markdown]
# <a href="https://colab.research.google.com/github/tordukhanov/DataScience-Demo-2025/blob/master/data_science_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Ingest

# %% [markdown]
# ## EDA

# %%
##Class !

# %% [markdown]
# ##Modeling

# %%
## Classification Modeling

# %% [markdown]
# ##Class A

# %% [markdown]
# ##Classification Algorithm A

# %% [markdown]
# ##Conclusion

# %% [markdown]
# ##Conclusion 2

# %% [markdown]
# # New Section
